# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
train_w_p=np.zeros(10)
test_w_p=np.zeros(10)
whole_w_p=np.zeros(10)

# %%
# ----------failed----------------
# BayesianRidge
train_w_p[0] =  0.10674100366338017
test_w_p[0]=  0.12445412956292763
whole_w_p[0] =  0.1120586214455504
# train均方误差 =  0.13050166329496052
# test均方误差 =  0.1317521043548339
# 整体均方误差 =  0.13087705539984634
# ElasticNetCV
# ----------begin----------------
train_w_p[1] =  0.10771392049915864
test_w_p[1] =  0.12646353762232962
whole_w_p[1] =  0.11334270098592776
# train均方误差 =  0.12733650166938631
# test均方误差 =  0.13090577374653684
# 整体均方误差 =  0.12840802483105168'

# LassoCV
# ----------begin----------------
train_w_p[2] =  0.10638711633286439
test_w_p[2] =  0.1230550752841858
whole_w_p[2] =  0.11139096689061913

#  LassoLarsCV
# ----------begin----------------
train_w_p[3] =  0.10637633567358222
test_w_p[3] =  0.12354977069031062
whole_w_p[3] =  0.1115319340667621

#  LinearRegression
# ----------begin----------------
train_w_p[4] =  0.10948295194122916
test_w_p[4] =  0.12886665815327414
whole_w_p[4] =  0.11530209089062077

#  RidgeCV
train_w_p[5] =  0.10808597932436956
test_w_p[5] =  0.12737752407004144
whole_w_p[5] =  0.1138774506867302

#  SGDRegressor
# ----------begin----------------
train_w_p[6] =  0.11591063794146944
test_w_p[6] =  0.13403386375664786
whole_w_p[6] =  0.12135137089914247


#  TheilSenRegressor
# ----------begin----------------
train_w_p[7] =  0.110591084247665
test_w_p[7] =  0.131448623643534
whole_w_p[7]=  0.1168526793502337

# %%
fig=plt.figure(figsize=(15,6))
total_num=8
labels = [ 'BayesianRidge','ElasticNetCV','LassoCV','LassoLarsCV','LinearRegression','RidgeCV',   'SGDRegressor','TheilSenRegressor']


# You can specify a rotation for the tick labels in degrees or with keywords.

plt.plot(train_w_p[:total_num],label='train')
plt.plot(train_w_p[:total_num],'o')
plt.plot(test_w_p[:total_num],label='test')
plt.plot(test_w_p[:total_num],'o')

plt.plot(whole_w_p[:total_num],label='whole')
plt.plot(whole_w_p[:total_num],'o')

plt.xticks(range(total_num), labels, rotation=70)#'vertical')
plt.ylabel('MSE')
plt.legend()
plt.title('MSE under different method')
plt.show()

# %%
test_end=np.zeros(8)

# %%
# BayesianRidge
# ElasticNetCV
# LassoCV
#  LassoLarsCV
#  LinearRegression
#  RidgeCV
#  SGDRegressor
#  TheilSenRegressor

# %%
for i in range(total_num):
    print('test_end['+str(i)+']=')
# Out:
# test_end[0]=
# test_end[1]=
# test_end[2]=
# test_end[3]=
# test_end[4]=
# test_end[5]=
# test_end[6]=
# test_end[7]=

# %%
test_end[0]=2.2390
test_end[1]=1.7641
test_end[2]=1.08
test_end[3]=2.21
test_end[4]=2.8599
test_end[5]=2.7975
test_end[6]=0.1723
test_end[7]=2.6301

# %%
fig=plt.figure(figsize=(15,6))
total_num=8
labels = [ 'BayesianRidge','ElasticNetCV','LassoCV','LassoLarsCV','LinearRegression','RidgeCV',   'SGDRegressor','TheilSenRegressor']


# You can specify a rotation for the tick labels in degrees or with keywords.

plt.plot(test_end[:total_num],label='test')
plt.plot(test_end[:total_num],'o')
plt.plot(test_w_p[:total_num],label='test of train')
plt.plot(test_w_p[:total_num],'o')

plt.xticks(range(total_num), labels, rotation=70)#'vertical')
plt.ylabel('MSE')
plt.legend()
plt.title('MSE under different method between train and test')
plt.show()

# %%
SGD


日期:2021-05-15 16:53:08排名: 无
score:0.1871

来自 <https://tianchi.aliyun.com/competition/entrance/231693/score> 

bayiesian ridge
2.2390


huger

2.6842


ridgecv
2.7975


sgd 去掉两个维度

0.1723

elasticcv

1.7641


linear

2.8599

theil
2.6301


Lasso

1.08

LassoLars

2.21

来自 <https://tianchi.aliyun.com/competition/entrance/231693/score>
